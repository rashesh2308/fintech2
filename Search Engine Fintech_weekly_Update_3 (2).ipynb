# %% [markdown]
# ## Table of contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#1.-Importing-Required-Libraries-and-Data"> Importing Required Libraries and Data</a></li>
#         <li><a href="#2.-Data-Pre-processing-and-Preparation"> Data Pre-processing and Preparation</a></li>
#         <li><a href="#3.-verison_1 - Search Engine Using Fuzzy-Wuzzy Library"> Search Engine Using Fuzzy-Wuzzy Library</a></li>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# ## Importing Libraries and Data

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import rapidfuzz
from rapidfuzz import process, utils

import spacy
from tqdm import tqdm

from re import sub
from gensim.utils import simple_preprocess

from nltk.tokenize import word_tokenize
import nltk

from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

import spacy
from rank_bm25 import BM25Okapi
from tqdm import tqdm
import timeit

import pandas as pd

# %%
#importing the file

dashboards = pd.read_csv('microstrategy_and_dashboard.csv')
metrics = pd.read_csv('tableau_metric.csv')

# %%
dashboards.head()
# Out:
#        id                      dashboards  \
# 0  139444                     Ad Analysis
# 1  139443                        Ad Recap
# 2  139434  Aggregate Sales per Pt vs. CWD
# 3  139466                   Brand Control
# 4  139465      Brand In and Out Scorecard
#
#                                              caption  \
# 0  Beer Style Level Value|Beer Style Levels|Beer ...
# 1  Beer Style Level Value|Beer Style Levels|Beer ...
# 2  Beer Style Level Value|Beer Style Levels|Beer ...
# 3  Brand Family|Brand Levels|Brand|Main Brand Fam...
# 4                               Segment|Time as Date
#
#                    datasource  \
# 0               IRI 52wk 34.0
# 1               IRI 52wk 34.0
# 2  IRI 52wk 34.0|IRI Agg 34.0
# 3               IRI 52wk 34.0
# 4               IRI 52wk 34.0
#
#                                                  url  Global_usage  \
# 0  https:andanddashboards.armadilloinsight.comand...          1717
# 1  https:andanddashboards.armadilloinsight.comand...           974
# 2  https:andanddashboards.armadilloinsight.comand...           851
# 3  https:andanddashboards.armadilloinsight.comand...           923
# 4  https:andanddashboards.armadilloinsight.comand...           876
#
#    users_id_1  user_id_2
# 0         532       1185
# 1         523        451
# 2         422        429
# 3         625        298
# 4         520        356

# %%
metrics.head()
# Out:
#    id              metric_name  \
# 0   0  Sales Measure Selection
# 1   1             Brand Levels
# 2   3        Beer Style Levels
# 3   4    Brands and Skew Value
# 4   5               Beer Style
#
#                                          descriptors
# 0  Dollar Sales|Dollar Sales|Dollar Sales Change ...
# 1  Brand Family|Vendor|Brand Family|Brand|Sku|Seg...
# 2  Beer Style Value|Macro Style Value|Mezzo Style...
# 3                         Brand Family|Brand|Segment
# 4  AMBER ALE|AMBER LAGE|BARLEY WINE|BELGIAN ALES|...

# %%
#converting column values to lowercase

dashboards = dashboards.apply(lambda x: x.astype(str).str.lower())
metrics = metrics.apply(lambda x: x.astype(str).str.lower())

# %%
#splitting caption and descriptors columns 

dashboards = dashboards[['dashboards','caption','Global_usage']]
dashboards['metric_names'] = dashboards.caption.str.split('|')
metrics['descriptors'] = metrics.descriptors.str.split('|')

# %%
#converting metric names and descriptors in each row values to multiple rows

spl_dashboards = dashboards.set_index(['dashboards'])['metric_names'].apply(pd.Series).stack().reset_index().drop('level_1', axis=1).rename(columns={0:'caption'})
spl_metrics = metrics.set_index(['metric_name'])['descriptors'].apply(pd.Series).stack().reset_index().drop('level_1', axis=1).rename(columns={0:'descriptors'})

# %%
#merging dashboards, metrics and descriptors

master = spl_dashboards.merge(spl_metrics, how = 'inner', left_on ='caption', right_on = 'metric_name')[['dashboards','caption','descriptors']]
master = master.rename(columns={"caption": "metrics"})
master
# Out:
#              dashboards                 metrics        descriptors
# 0           ad analysis  beer style level value  macro style value
# 1           ad analysis  beer style level value  mezzo style value
# 2           ad analysis  beer style level value   micro style valu
# 3           ad analysis  beer style level value   beer style value
# 4           ad analysis  beer style level value            altbier
# ...                 ...                     ...                ...
# 236553  surveyed stores         surveyed stores               2018
# 236554  surveyed stores         surveyed stores               2019
# 236555  surveyed stores         surveyed stores               2020
# 236556  surveyed stores         surveyed stores               2021
# 236557  surveyed stores                  survey      survey number
#
# [236558 rows x 3 columns]

# %% [markdown]
# # Creating Corpus

# %%
#creating corpus

dashboards_list = list(master.dashboards.unique())
metrics_list = list(master.metrics.unique())
descriptors_list = list(master.descriptors.unique())
mastercorpus = dashboards_list + metrics_list + descriptors_list

# %%
#pre-processing corpus

mastercorpus = list(filter(None,mastercorpus))

# %% [markdown]
# ### Pre-Processing Steps :
# - stop words
# - lower case
# - stemming
# - lemmatization
# - noun filter
#
# ### Search Suggestions flow :
# - Fuzzywuzzy suggestion (includes dashboard title, metric names and descriptors)
# - Dashboard names extraction
# - Final suggestions (popularity of dashboard)
#
# ### Efficient approaches:
#
# - storing metric and descriptors as keys, and dashboards names as values in a dictionary
# - weightage to dashboard names, followed by metric and descriptors

# %% [markdown]
# # Basline Model
# ## Method 1: RegEx string matching

# %%
import re
from re import match

# %%
start = timeit.default_timer()
r = re.compile(".*mezzo")
newlist = list(filter(r.match, mastercorpus))
stop = timeit.default_timer()
execution_time = stop - start

print("Program Executed in "+str(execution_time))
print(newlist)
# Out:
# Program Executed in 0.006374348000463215
# ['mezzo style value', 'mezzo spritz virtue cider brand family', 'café intermezzo nashville (97587)']

# %% [markdown]
# ### Disadvantage:
# It won't be able to handle the spelling mistakes from the user.

# %% [markdown]
# ## Method 2: Using fuzzywuzzy Library

# %%
def fuzzywuzzy_suggestion(corpus, input_query):
    for i in [corpus]:
        return process.extract(input_query, i, limit=10)
        
def dashboard_names_suggestion(dashboards, Fuzzy_suggestions):
    start_time = time.time()
    dashboard_names = []
       
    for i in Fuzzy_suggestions:
        if i[0] in dashboards_list:  
            dashboard_names.append(i[0])
        elif i[0] in metrics_list:   
            dashboard_names = dashboard_names + (dashboards.loc[(dashboards.metrics.str.lower() == i[0].lower())].dashboards).to_list()
        else: 
            dashboard_names = dashboard_names + (dashboards.loc[(dashboards.descriptors.str.lower() == i[0].lower())].dashboards).to_list()
            end_time = time.time()
    return dashboard_names

# %%
# Input query:
start = timeit.default_timer()
suggestion = fuzzywuzzy_suggestion(mastercorpus,'sales')
print(suggestion)

dashboard_suggestions = list(dashboard_names_suggestion(master,suggestion))

search_output = []
search_output = list(dict.fromkeys(dashboard_suggestions))


stop = timeit.default_timer()
execution_time = stop - start

print("Program Executed in "+str(execution_time))
search_output[:10]
# Out:
# [('aggregate sales per pt vs. cwd', 90.0, 2), ('sales per pt vs. cwd', 90.0, 32), ('sales team opportunitshis year ', 90.0, 55), ('sales manager dashboard', 90.0, 56), ('sales team tracker ', 90.0, 59), ('sales team gains and losses', 90.0, 60), ('sales measure selection', 90.0, 84), ('sales state', 90.0, 130), ('dollar sales', 90.0, 802), ('dollar sales change ya', 90.0, 803)]
# Program Executed in 0.4486926549998316
# ['aggregate sales per pt vs. cwd',
#  'sales per pt vs. cwd',
#  'sales team opportunitshis year ',
#  'sales manager dashboard',
#  'sales team tracker ',
#  'sales team gains and losses',
#  'ad analysis',
#  'r geography over time',
#  'category and segment analysis',
#  'competitive set']

# %% [markdown]
# ## Method 3:  Using FuzzyWuzzy with Global Usage of Dashboards

# %%
dashboards.Global_usage = pd.to_numeric(dashboards.Global_usage)

# %%
dashboards[dashboards['dashboards'].isin(search_output)].sort_values(by = 'Global_usage',ascending = False)
dashboards.head()
# Out:
#                        dashboards  \
# 0                     ad analysis
# 1                        ad recap
# 2  aggregate sales per pt vs. cwd
# 3                   brand control
# 4      brand in and out scorecard
#
#                                              caption  Global_usage  \
# 0  beer style level value|beer style levels|beer ...          1717
# 1  beer style level value|beer style levels|beer ...           974
# 2  beer style level value|beer style levels|beer ...           851
# 3  brand family|brand levels|brand|main brand fam...           923
# 4                               segment|time as date           876
#
#                                         metric_names
# 0  [beer style level value, beer style levels, be...
# 1  [beer style level value, beer style levels, be...
# 2  [beer style level value, beer style levels, be...
# 3  [brand family, brand levels, brand, main brand...
# 4                            [segment, time as date]

# %%
def popular_dashboard_suggestion(dashboards, dashboardSuggestion): 
    return dashboards[dashboards['dashboards'].isin(dashboardSuggestion)].sort_values(by = 'Global_usage',
                                                                      ascending = False)[['dashboards',
                                                                                          'Global_usage']]

# %%
#popular dashboard suggestions
start = timeit.default_timer()
x = popular_dashboard_suggestion(dashboards,search_output).head(10)
stop = timeit.default_timer()
execution_time = stop - start

print("Program Executed in "+str(execution_time))
print(x)
# Out:
# Program Executed in 0.00295383499997115
#                        dashboards  Global_usage
# 16         dollar ranker with cwd          7540
# 12  category and segment analysis          4583
# 15               dollar rank comp          4255
# 42                 style analysis          3556
# 40                        rankers          2535
# 36                 price analysis          2114
# 24          market index analysis          2012
# 0                     ad analysis          1717
# 6             brewery comparisons          1712
# 32                     our brands          1456

# %%
#df_new[df_new.caption.str.lower() == 'select main vendor']

# %%
# checking dashboard_names for metric = 'segment'
#string = 'Geography'.lower()
#print(df_new.loc[df_new.caption.str.lower() == string])
#print(df_new.loc[df_new.caption.str.lower() == 'geography'].count())

# %%
#dashboards[dashboards['dashboards'].isin(dasboard_names_2)].sort_values(by = 'popularity', ascending = False)

# %%
#popular_suggestions = popular_dashboard_suggestion(df,dasboard_names_2)
#print(len(popular_suggestions))
#popular_suggestions

# %%
# dashboard_names=[]
# for i in suggestion:
#         print(i[0])
#         for key, value in dict_dashboard_metric.items():
#                 for v in value:
# #                     print(v)
# #                     print(type(i[0]),type(v))
#                     if i[0] == v:
# #                         print('no')
#                         dashboard_names.append(key)
# dashboard_names

# def dashboard_name_suggestion(suggestion, dict1,dict2):
#     list_of_keys =[]
#     for value in suggestion:
      
#         list_of_keys.append([key for key, list_of_values in dict1.items()
#                 if value[0] in list_of_values])
#         list_of_keys.append([key for key, list_of_values in dict2.items()
#                 if value[0] in list_of_values])
#         return list_of_keys

# %% [markdown]
# ## Method 4: Using auto-suggestion of dashboard names

# %%
from fast_autocomplete import AutoComplete

# %%
dashboard_dict = dict(enumerate(master.dashboards.unique().flatten(), 1))
dashboard_dict = {v: k  for k,v in dashboard_dict.items()}
dashboard_dict

metric_dict = dict(enumerate(master.metrics.unique().flatten(), 1))
metric_dict = {v: k  for k,v in metric_dict.items()}
metric_dict

descriptor_dict = dict(enumerate(master.descriptors.unique().flatten(), 1))
descriptor_dict = {v: k  for k,v in descriptor_dict.items()}
descriptor_dict


# metric_dict = df_final.caption.unique().to_dict()
# descriptor_dict = df_final.descriptor.unique().to_dict()
# Out:
# {'macro style value': 1,
#  'mezzo style value': 2,
#  'micro style valu': 3,
#  'beer style value': 4,
#  'altbier': 5,
#  'american amber or red ale': 6,
#  'american brown ale': 7,
#  'american ipa': 8,
#  'american lager': 9,
#  'american light lager': 10,
#  'american pale le': 11,
#  'american porter': 12,
#  'american stout': 13,
#  'american wild ale': 14,
#  'anniversary release': 15,
#  'baltic porter': 16,
#  'barleywine': 17,
#  'barrel aged specialty': 18,
#  'beer flagship plus mix pack': 19,
#  'belgian upa': 20,
#  'belgian pale ale': 21,
#  'berliner weisse': 22,
#  'blonde ale': 23,
#  'bock': 24,
#  'california common beer': 25,
#  'citrus flavored neutral base': 26,
#  'collaboration beer': 27,
#  'cream ale': 28,
#  'doppelbock': 29,
#  'dubbel': 30,
#  'dunkel': 31,
#  'english brown ale': 32,
#  'english foreign or export stout': 33,
#  'english ia': 34,
#  'english pale ale': 35,
#  'esb': 36,
#  'flanders': 37,
#  'fruit ipa': 38,
#  'fruit specialty': 39,
#  'gose or gueuze': 40,
#  'hefeweizen': 41,
#  'helles': 42,
#  'herb or spice specialty': 43,
#  'imperial brown ale': 44,
#  'imperial ipa': 45,
#  'imperial porter': 46,
#  'imperial red ale': 47,
#  'imperial stout': 48,
#  'ia mix pack': 49,
#  'irish red': 50,
#  'kolsch': 51,
#  'lambic': 52,
#  'maibock': 53,
#  'new england or hazy ipa': 54,
#  'oatmeal stout': 55,
#  'other beer mix pack': 56,
#  'other belgian ale': 57,
#  'other dark lager': 58,
#  'other ipa': 59,
#  'other pale lager': 60,
#  'other porter': 61,
#  'other special release': 62,
#  'other specialty': 63,
#  'other stout': 64,
#  'other strong ales': 65,
#  'other wheat ale': 66,
#  'other wild or sour ale': 67,
#  'pilsner': 68,
#  'quadrupel': 69,
#  'saison or farmhouse ale': 70,
#  'scothch ale or wee heavy': 71,
#  'scottish ale': 72,
#  'seasonal mix pack': 73,
#  'seasonal release': 74,
#  'series release': 75,
#  'session ipa': 76,
#  'shandy or radler specialty': 77,
#  'smoked porter': 78,
#  'sour ale': 79,
#  'sweet or milk stout': 80,
#  'tripel': 81,
#  'vienna amber or red lager': 82,
#  'west coast ipa': 83,
#  'wheat ale': 84,
#  'witbier': 85,
#  'micro style value': 86,
#  'amber ale': 87,
#  'amber lage': 88,
#  'barley wine': 89,
#  'belgian ales': 90,
#  'belgian wits': 91,
#  'bocks': 92,
#  'brown beer': 93,
#  'dark beer': 94,
#  'fmb': 95,
#  'fruit/veggie/spiced': 96,
#  'golden ales': 97,
#  'ipa': 98,
#  'light beer': 99,
#  'other pale lagers': 100,
#  'pale ale': 101,
#  'porter': 102,
#  'red beer': 103,
#  'saison/farmhouse ales': 104,
#  'scottish': 105,
#  'seasonal': 106,
#  'spec relse/speclty/coll': 107,
#  'stout': 108,
#  'strong ales': 109,
#  'variety': 110,
#  'wheat beer': 111,
#  'brand overlay': 112,
#  'brand family value': 113,
#  '2nd shift brand family': 114,
#  '4 noses brand family': 115,
#  '3 sons brand family': 116,
#  '21st amendment brand family': 117,
#  'abita brand family': 118,
#  'abomination brand family': 119,
#  'against the grain brand family': 120,
#  'alaskan brand family': 121,
#  'alesmith brnad family': 122,
#  'almanac brand family': 123,
#  'alpine beer brnad family': 124,
#  'american solera brand family': 125,
#  'anchor brand family': 126,
#  'anchorage brand family': 127,
#  'anderson valley brand family': 128,
#  'arrogant brand family': 129,
#  'aspen brand family': 130,
#  'august schell brand family': 131,
#  'avery brand family': 132,
#  'ballast point brand family': 133,
#  'bards tale brand family': 134,
#  'barrel house brand family': 135,
#  'bayhawk brand family': 136,
#  'beachwood brand family': 137,
#  'bear republic brand family': 138,
#  'beared iris brand family': 139,
#  'bells brand family': 140,
#  'bend brand family': 141,
#  'bent paddle brand family': 142,
#  'big sky brand family': 143,
#  'bira 91 brand family': 144,
#  'bissel brothers brand family': 145,
#  'black bottle brand family': 146,
#  'balckberry farm brand family': 147,
#  'bonfire brand family': 148,
#  'bootstrap brand family': 149,
#  'bosque brand family': 150,
#  'boulder brand family': 151,
#  'boulevard brand family': 152,
#  'bravus brand family': 153,
#  'breakside brand family': 154,
#  'brew link brand family': 155,
#  'brewery bhavana brand family': 156,
#  'birdgeport brand family': 157,
#  'bristol brand family': 158,
#  'brooklyn brand family': 159,
#  'brouwerj craft brand family': 160,
#  'bruery terreux rband family': 161,
#  'calidad brand family': 162,
#  'canarchy brand family': 163,
#  'canarchy brnad family': 164,
#  'captain lawrence brand family': 165,
#  '69th regiment brands': 166,
#  'berentzen': 167,
#  'charron favreau': 168,
#  'espiritus group': 169,
#  'lost distillery': 170,
#  'pacific plate': 171,
#  'pure holdings': 172,
#  'brand family': 173,
#  'vendor': 174,
#  'brand': 175,
#  'sku': 176,
#  'segment': 177,
#  'package skew size': 178,
#  '11 ct 22 oz bottle': 179,
#  '12 ct 1 oz can': 180,
#  '12 ct 4 oz bottle': 181,
#  '12 ct 6 oz bottle': 182,
#  '12 ct 11 oz bottle': 183,
#  '12 ct 11 oz can': 184,
#  '12 ct 11  12 oz bottle': 185,
#  '12 ct 11  12 oz can': 186,
#  '12 ct 12 oz bottle': 187,
#  '12 ct 12 oz can': 188,
#  '12 ct 12 oz other': 189,
#  '12 ct 14 oz can': 190,
#  '12 ct 16 oz bottle': 191,
#  '12 ct 16 oz can': 192,
#  '12 ct 17 oz bottle': 193,
#  '12 ct 17 oz can': 194,
#  '12 ct 19 oz bottle': 195,
#  '12 ct 19 oz can': 196,
#  '12 ct 22 oz bottle': 197,
#  '12 ct 22 oz can': 198,
#  '12 ct 24 oz bottle': 199,
#  '12 ct 24 oz can': 200,
#  '12 ct 25 oz bottle': 201,
#  '12 ct 25 oz can': 202,
#  '12 ct 32 oz bottle': 203,
#  '12 ct 32 oz can': 204,
#  '12 ct 40 oz bottle': 205,
#  '11 ct 7 oz bottle': 206,
#  '12 ct 10 oz bottle': 207,
#  '12 ct 10 oz can': 208,
#  '12 ct 6 oz can': 209,
#  '12 ct 7 oz bottle': 210,
#  '12 ct 8 oz bottle': 211,
#  '12 ct 8 oz can': 212,
#  '12 ct 9 oz bottle': 213,
#  '12 ct 9 oz can': 214,
#  '13 ct 12 oz bottle': 215,
#  '13 ct 12 oz can': 216,
#  '15 ct 11 oz bottle': 217,
#  '15 ct 11 oz can': 218,
#  '15 ct 12 oz bottle': 219,
#  '15 ct 12 oz can': 220,
#  '16 ct 12 oz can': 221,
#  '18 ct 11 oz bottle': 222,
#  '18 ct 12 oz bottle': 223,
#  '18 ct 12 oz can': 224,
#  '15 ct 16 oz bottle': 225,
#  '15 ct 16 oz can': 226,
#  '15 ct 18 oz bottle': 227,
#  '16 ct 16 oz can': 228,
#  '18 ct 15 oz can': 229,
#  '18 ct 16 oz bottle': 230,
#  '18 ct 16 oz can': 231,
#  '15 ct 22 oz bottle': 232,
#  '15 ct 24 oz can': 233,
#  '18 ct 19.2 oz can': 234,
#  '15 ct 25 oz can': 235,
#  '16 ct 7 oz bottle': 236,
#  '18 ct 10 oz other': 237,
#  '18 ct 8 oz can': 238,
#  '2 ct 11 oz bottle': 239,
#  '2 ct 12 oz bottle': 240,
#  '2 ct 12 oz can': 241,
#  '3 ct 11 oz bottle': 242,
#  '3 ct 12 oz bottle': 243,
#  '2 ct 16 oz can': 244,
#  '2 ct 17 oz bottle': 245,
#  '3 ct 16 oz can': 246,
#  '2 ct 22 oz bottle': 247,
#  '3 ct 19 oz bottle': 248,
#  '3 ct 22 oz bottle': 249,
#  '3 ct 24 oz can': 250,
#  '2 ct 25 oz bottle': 251,
#  '3 ct 25 oz bottle': 252,
#  '3 ct 25 oz can': 253,
#  '3 ct 8 oz bottle': 254,
#  '20 ct 12 oz bottle': 255,
#  '20 ct 12 oz can': 256,
#  '20 ct 15 oz can': 257,
#  '20 ct 16 oz bottle': 258,
#  '20 ct 17 oz bottle': 259,
#  '20 ct 17 oz can': 260,
#  '20 ct 10 oz bottle': 261,
#  '20 ct 7 oz bottle': 262,
#  '24 ct 10 oz can': 263,
#  '24 ct 11 oz bottle': 264,
#  '24 ct 11 oz can': 265,
#  '24 ct 11  12 oz bottle': 266,
#  '24 ct 11  12 oz can': 267,
#  '24 ct 12 oz bottle': 268,
#  '24 ct 12 oz can': 269,
#  '24 ct bottle': 270,
#  '24 ct 15 oz bottle': 271,
#  '24 ct 15 oz can': 272,
#  '24 ct 16 oz bottle': 273,
#  '24 ct 16 oz can': 274,
#  '24 ct 16.9 oz can': 275,
#  '24 ct 17 oz bottle': 276,
#  '24 ct 17 oz can': 277,
#  '24 ct 6 oz bottle': 278,
#  '24 ct 7 oz bottle': 279,
#  '24 ct 8 oz bottle': 280,
#  '24 ct 8 oz can': 281,
#  '24 ct 9 oz bottle': 282,
#  '24 ct 9 oz can': 283,
#  '28 ct 12 oz bottle': 284,
#  '30 ct 12 oz bottle': 285,
#  '30 ct 12 oz can': 286,
#  '36 ct 12 oz can': 287,
#  '4 ct 1 lt bottle': 288,
#  '4 ct 4 oz can': 289,
#  '4 ct 5 oz can': 290,
#  '4 ct 11 oz bottle': 291,
#  '4 ct 11 oz can': 292,
#  '4 ct 11 oz other': 293,
#  '4 ct 11  12 oz bottle': 294,
#  '4 ct 11  12 oz can': 295,
#  '4 ct 12 oz bottle': 296,
#  '4 ct 12 oz can': 297,
#  '4 ct 12.7 oz bottle': 298,
#  '4 ct 13 oz bottle': 299,
#  '4 ct 14 oz bottle': 300,
#  '4 ct 14 oz can': 301,
#  '4 ct 15 oz bottle': 302,
#  '4 ct 15 oz can': 303,
#  '4 ct 16 oz bottle': 304,
#  '4 ct 16 oz can': 305,
#  '4 ct 16.2 oz can': 306,
#  '4 ct 16.9 oz bottle': 307,
#  '4 ct 16.9 oz can': 308,
#  '4 ct 17 oz bottle': 309,
#  '4 ct 17 oz can': 310,
#  '4 ct 18 oz can': 311,
#  '4 ct 19 oz can': 312,
#  '4 ct 22 oz bottle': 313,
#  '4 ct 22 oz can': 314,
#  '4 ct 10 oz bottle': 315,
#  '4 ct 10 oz other': 316,
#  '4 ct 7 oz can': 317,
#  '4 ct 8 oz bottle': 318,
#  '4 ct 8 oz can': 319,
#  '4 ct 8.5 oz can': 320,
#  '4 ct 9 oz bottle': 321,
#  '4 ct 9 oz can': 322,
#  '5 ct 3 oz bottle': 323,
#  '6 ct 2 oz can': 324,
#  '5 ct 11 oz bottle': 325,
#  '5 ct 12 oz bottle': 326,
#  '6 ct 10 oz bottle': 327,
#  '6 ct 10 oz can': 328,
#  '6 ct 11 oz bottle': 329,
#  '6 ct 11 oz can': 330,
#  '6 ct 11  12 oz bottle': 331,
#  '6 ct 11  12 oz can': 332,
#  '6 ct 11.2 oz bottle': 333,
#  '6 ct 11.2 oz can': 334,
#  '6 ct 11.8 oz can': 335,
#  '6 ct 12 oz bottle': 336,
#  '6 ct 12 oz can': 337,
#  '6 ct 12.7 oz can': 338,
#  '6 ct 13 oz bottle': 339,
#  '6 ct 2 oz bottle': 340,
#  '5 ct 17 oz bottle': 341,
#  '6 ct 14 oz can': 342,
#  '6 ct 16 oz bottle': 343,
#  '6 ct 16 oz can': 344,
#  '6 ct 17 oz can': 345,
#  '6 ct 20 oz bottle': 346,
#  '6 ct 22 oz bottle': 347,
#  '6 ct 24 oz can': 348,
#  '5 ct 25 oz bottle': 349,
#  '6 ct 25 oz bottle': 350,
#  '6 ct 7 oz bottle': 351,
#  '6 ct 8 oz bottle': 352,
#  '6 ct 8 oz can': 353,
#  '6 ct 9 oz bottle': 354,
#  '6 ct 9 oz can': 355,
#  '7 ct 12 oz bottle': 356,
#  '10 ct 11 oz bottle': 357,
#  '10 ct 12 oz bottle': 358,
#  '10 ct 12 oz can': 359,
#  '8 ct 11 oz bottle': 360,
#  '8 ct 11 oz can': 361,
#  '8 ct 12 oz bottle': 362,
#  '8 ct 12 oz can': 363,
#  '9 ct 12 oz bottle': 364,
#  '9 ct 12 oz can': 365,
#  '10 ct 15 oz can': 366,
#  '10 ct 16 oz can': 367,
#  '10 ct 17 oz bottle': 368,
#  '8 ct 15 oz can': 369,
#  '8 ct 16 oz bottle': 370,
#  '8 ct 16 oz can': 371,
#  '8 ct 17 oz bottle': 372,
#  '8 ct 17 oz can': 373,
#  '9 ct 16 oz bottle': 374,
#  '9 ct 16 oz can': 375,
#  '9 ct 16oz can': 376,
#  '9 ct 17 oz bottle': 377,
#  '8 ct 7 oz bottle': 378,
#  '1 ct 1690 oz other': 379,
#  '1 ct 1984 oz other': 380,
#  '1 ct 2016 oz other': 381,
#  '1 ct 2048 oz other': 382,
#  '1 ct 496 oz other': 383,
#  '1 ct 661 oz other': 384,
#  '1 ct 992 oz other': 385,
#  '1 ct keg 2048 oz other': 386,
#  '1 ct 11 oz bottle': 387,
#  '1 ct 11 oz can': 388,
#  '1 ct 11  12 oz bottle': 389,
#  '1 ct 11  12 oz can': 390,
#  '1 ct 12 oz bottle': 391,
#  '1 ct 12 oz can': 392,
#  '1 ct 12 oz other': 393,
#  '1 ct 12.7 oz bottle': 394,
#  '1 ct 13 oz bottle': 395,
#  '1 ct 13 oz can': 396,
#  '1 ct 14 oz bottle': 397,
#  '1 ct 14 oz can': 398,
#  '1 ct 15 oz bottle': 399,
#  '1 ct 15 oz can': 400,
#  '1 ct 16 oz bottle': 401,
#  '1 ct 16 oz can': 402,
#  '1 ct 16.9 oz bottle': 403,
#  '1 ct 16.9 oz can': 404,
#  '1 ct 17 oz bottle': 405,
#  '1 ct 17 oz can': 406,
#  '1 ct 18 oz bottle': 407,
#  '1 ct 18.6 oz bottle': 408,
#  '1 ct long neck bottle 14.88 oz bottle': 409,
#  '1 ct 19 oz bottle': 410,
#  '1 ct 19 oz can': 411,
#  '1 ct 19.2 oz bottle': 412,
#  '1 ct 19.2 oz can': 413,
#  '1 ct 20 oz bottle': 414,
#  '1 ct 21 oz bottle': 415,
#  '1 ct 22 oz bottle': 416,
#  '1 ct 22 oz can': 417,
#  '1 ct 22 oz other': 418,
#  '1 ct 23 oz bottle': 419,
#  '1 ct 23 oz can': 420,
#  '1 ct 23.7 oz bottle': 421,
#  '1 ct 23.7 oz can': 422,
#  '1 ct 24 oz bottle': 423,
#  '1 ct 24 oz can': 424,
#  '1 ct 24 oz other': 425,
#  '1 ct 24.3 oz bottle': 426,
#  '1 ct 25 oz bottle': 427,
#  '1 ct 25 oz can': 428,
#  '1 ct 25.4 oz bottle': 429,
#  '1 ct 26 oz bottle': 430,
#  '1 ct 32 oz bottle': 431,
#  '1 ct 32 oz can': 432,
#  '1 ct 32 oz other': 433,
#  '1 ct 33.8 oz bottle': 434,
#  '1 ct 34 oz bottle': 435,
#  '1 ct 34 oz can': 436,
#  '1 ct 34 oz other': 437,
#  '1 ct 40 oz bottle': 438,
#  '1 ct 40 oz can': 439,
#  '1 ct can 32.12 oz can': 440,
#  '1 ct 10 oz bottle': 441,
#  '1 ct 10 oz can': 442,
#  '1 ct 10 oz other': 443,
#  '1 ct 6.8 oz bottle': 444,
#  '1 ct 7 oz bottle': 445,
#  '1 ct 8 oz bottle': 446,
#  '1 ct 8 oz can': 447,
#  '1 ct 9 oz bottle': 448,
#  '1 ct 9 oz can': 449,
#  '1 ct 101 oz bottle': 450,
#  '1 ct 101 oz other': 451,
#  '1 ct 101.4 oz bottle': 452,
#  '1 ct 101.4 oz other': 453,
#  '1 ct 102 oz bottle': 454,
#  '1 ct 128 oz other': 455,
#  '1 ct 169 oz other': 456,
#  '1 ct 192 oz other': 457,
#  '1 ct 260 oz other': 458,
#  '1 ct 330 oz other': 459,
#  '1 ct 406 oz bottle': 460,
#  '1 ct 51 oz bottle': 461,
#  '1 ct 51 oz other': 462,
#  '1 ct 59 oz bottle': 463,
#  '1 ct 64 oz bottle': 464,
#  '1 ct 64 oz can': 465,
#  '1 ct 64 oz other': 466,
#  '1 ct 66.7 oz bottle': 467,
#  '1 ct 660 oz other': 468,
#  '1 ct 666 oz other': 469,
#  '1 ct 68 oz bottle': 470,
#  '1 ct 68 oz can': 471,
#  '1 ct 72 oz bottle': 472,
#  '1 ct 42 oz bottle': 473,
#  '1 ct 5 oz bottle': 474,
#  '1 ct bottle': 475,
#  '1 ct can': 476,
#  'bottle': 477,
#  'can': 478,
#  'other': 479,
#  'dollar sales': 480,
#  'dollar sales change ya': 481,
#  'volume sales': 482,
#  'volume sales change ya': 483,
#  'dollar sales per percent last year': 484,
#  'dollar sales per pt change ya': 485,
#  'volume sales per point': 486,
#  'volume sales per percent last year': 487,
#  'volume sales per pt change ya': 488,
#  'cwd ly': 489,
#  'cwd change ya': 490,
#  'cwd trend last year': 491,
#  'avg items per store cwd (max)': 492,
#  'iri': 493,
#  'assorted': 494,
#  'cider': 495,
#  'craft': 496,
#  'craftesque': 497,
#  'domestic premium': 498,
#  'domestic sub-premium': 499,
#  'domestic super premium': 500,
#  'faux craft': 501,
#  'flavored malt beverages': 502,
#  'import': 503,
#  'non-alcoholic': 504,
#  'package type': 505,
#  'beer style': 506,
#  'product': 507,
#  'volume sale': 508,
#  '1': 509,
#  '2': 510,
#  '3': 511,
#  '4': 512,
#  '5': 513,
#  '6': 514,
#  '7': 515,
#  '8': 516,
#  '9': 517,
#  '10': 518,
#  '11': 519,
#  '12': 520,
#  '13': 521,
#  '14': 522,
#  '15': 523,
#  '16': 524,
#  '17': 525,
#  '18': 526,
#  '19': 527,
#  '20': 528,
#  '21': 529,
#  '22': 530,
#  '23': 531,
#  '24': 532,
#  '25': 533,
#  '26': 534,
#  '27': 535,
#  '28': 536,
#  '29': 537,
#  '30': 538,
#  '31': 539,
#  '32': 540,
#  '33': 541,
#  '34': 542,
#  '36': 543,
#  '37': 544,
#  '38': 545,
#  '39': 546,
#  '40': 547,
#  '41': 548,
#  '42': 549,
#  '43': 550,
#  '44': 551,
#  '45': 552,
#  '46': 553,
#  '47': 554,
#  '48': 555,
#  '49': 556,
#  '50': 557,
#  '51': 558,
#  '52': 559,
#  '53': 560,
#  '54': 561,
#  '55': 562,
#  '56': 563,
#  '57': 564,
#  '58': 565,
#  '59': 566,
#  '60': 567,
#  '61': 568,
#  '62': 569,
#  '63': 570,
#  '64': 571,
#  '65': 572,
#  '66': 573,
#  '67': 574,
#  '68': 575,
#  '69': 576,
#  '70': 577,
#  '71': 578,
#  '72': 579,
#  '73': 580,
#  '74': 581,
#  '75': 582,
#  '76': 583,
#  '77': 584,
#  '78': 585,
#  '79': 586,
#  '80': 587,
#  'geography description': 588,
#  'categorical': 589,
#  'parameter': 590,
#  'filter': 591,
#  '3 percent': 592,
#  '3.5 percent': 593,
#  '3.6 percent': 594,
#  '3.7 percent': 595,
#  '3.8 percent': 596,
#  '3.9 percent': 597,
#  '4 percent': 598,
#  '4.1 percent': 599,
#  '4.2 percent': 600,
#  '4.3 percent': 601,
#  '4.4 percent': 602,
#  '4.5 percent': 603,
#  '4.6 percent': 604,
#  '4.7 percent': 605,
#  '4.8 percent': 606,
#  '4.9 percent': 607,
#  '4.75 percent': 608,
#  '4.85 percent': 609,
#  '5 percent': 610,
#  '5.1 percent': 611,
#  '5.2 percent': 612,
#  '5.3 percent': 613,
#  '5.4 percent': 614,
#  '5.5 percent': 615,
#  '5.6 percent': 616,
#  '5.7 percent': 617,
#  '5.8 percent': 618,
#  '5.9 percent': 619,
#  '5.12 percent': 620,
#  '5.25 percent': 621,
#  '5.35 percent': 622,
#  '5.75 percent': 623,
#  '5.93 percent': 624,
#  '6 percent': 625,
#  '6.1 percent': 626,
#  '6.2 percent': 627,
#  '6.3 percent': 628,
#  '6.4 percent': 629,
#  '6.5 percent': 630,
#  '6.6 percent': 631,
#  '6.7 percent': 632,
#  '6.8 percent': 633,
#  '6.9 percent': 634,
#  '7 percent': 635,
#  '7.1 percent': 636,
#  '7.2 percent': 637,
#  '7.3 percent': 638,
#  '7.4 percent': 639,
#  '7.5 percent': 640,
#  '7.6 percent': 641,
#  '7.7 percent': 642,
#  '7.8 percent': 643,
#  '7.9 percent': 644,
#  '8 percent': 645,
#  '8.1 percent': 646,
#  '8.2 percent': 647,
#  '8.3 percent': 648,
#  '8.4 percent': 649,
#  '8.5 percent': 650,
#  '8.6 percent': 651,
#  '8.7 percent': 652,
#  '8.8 percent': 653,
#  '8.9 percent': 654,
#  '9 percent': 655,
#  '9.1 percent': 656,
#  '9.2 percent': 657,
#  '93. percent': 658,
#  '9.4 percent': 659,
#  '9.5 percent': 660,
#  '9.6 percent': 661,
#  '9.7 percent': 662,
#  '9.8 percent': 663,
#  '9.9 percent': 664,
#  '10 percent': 665,
#  '11 percent': 666,
#  '12 percent': 667,
#  '13 percent': 668,
#  '14 percent': 669,
#  '15 percent': 670,
#  '16 percent': 671,
#  '18 percent ': 672,
#  'time as date ': 673,
#  'brand value': 674,
#  'vw iri current brand overlay': 675,
#  'odell ipa': 676,
#  'odell 90 shilling ale': 677,
#  'avery white rascal belgian style white ale': 678,
#  'odell sippin pretty fruited sour ale': 679,
#  'avery india pale ale': 680,
#  '4 noses bout damn time ipa': 681,
#  'ska seasonal': 682,
#  'odell rupture fresh grind ale': 683,
#  'odell myrcenary double ipa': 684,
#  'ska modus hoperandi ipa': 685,
#  'odell witkist grapefruit white ale': 686,
#  '4 noses raspberry blonde ale': 687,
#  'ska true blonde ale': 688,
#  'ska modus mandarina india pale ale': 689,
#  'prost pils pale german lager': 690,
#  'prost dunkel dark frankonian style lager': 691,
#  '4 noses perfect drift german style pilsner': 692,
#  'prost weissbier bavarian style wheat ale': 693,
#  'big sky moose drool brown ale': 694,
#  'avergy white rascal belgian style white ale': 695,
#  'dry dock apricot blonde ale': 696,
#  'avery variety pack': 697,
#  'dry dock variety pack': 698,
#  'avery stampede colorado gold lager': 699,
#  'fighting 69th regiment': 700,
#  'the fighting 69th regiment': 701,
#  'berentzen liqeur': 702,
#  'chareau': 703,
#  'gin lane': 704,
#  'corner creek': 705,
#  'ainneamh': 706,
#  'auchnagie': 707,
#  'benachie': 708,
#  'gerston': 709,
#  'lossit': 710,
#  'stratheden': 711,
#  'towiemore': 712,
#  'selvarey rum pomacai vodka': 713,
#  'purus organic vodka': 714,
#  'week ending ': 715,
#  'the fighting 69th regiment 6/750 40%': 716,
#  'the fighting 69th regiment irish whiskey 12/375ml 40%': 717,
#  'the fighting 69th regiment irish whiskey 6/750ml 40%': 718,
#  'berentzen apple liqueur 6/1000 20% uu': 719,
#  'berentzen apple liqueur 12/750 20%': 720,
#  'berentzen apple liqueur 6/100 20%': 721,
#  'berentzen bushel and barrel 120/50 30%': 722,
#  'berentzen pear 6/750 ml 15%': 723,
#  'berentzen wild cherry liqueur 12/750ml 30%': 724,
#  'chareau aloe liqueur 6/375ml 25%': 725,
#  'berentzen icemint schnapps 6/750 30%': 726,
#  'auchanagie archivist blended malt scoth whiskey tin pack 6/750 ml 46%': 727,
#  'auchnagie archivist pedro ximenez sherry finish 6/750ml 46%': 728,
#  'auchnagie archivist port finish 6/750ml 46%': 729,
#  'benachie classic slection 12/750ml 43% 750 l/12': 730,
#  'classic selection combo pack finish 6/750ml 43%': 731,
#  'gerston archivist selection rum finish 6/750 46%': 732,
#  'gerston blended malt scotch whisky 6/750 46%': 733,
#  'lossit classic selection 12/750ml43%': 734,
#  'lossit classic selection bordeaux finish 6/750ml 43%': 735,
#  'lossit classic selection olorosso sherry finish 6/750ml': 736,
#  'lossit classic selection port finish 6/750ml 43%': 737,
#  'lossit classic selection px finish 6/750ml43%': 738,
#  'lossit classic selection ribera del duero finish 6/750ml 43%': 739,
#  'lossit classic selection rum finish 6/750ml 43%': 740,
#  'stratheden blended malt scotch whiskey 6/750ml 46%': 741,
#  'stratheden vintage blended malt scotch whiskey 6/750ml 46%': 742,
#  'towiemore classic selection 12/750m 43%': 743,
#  'towiemore classic selection bordeaux finish 6/750ml 43%': 744,
#  'towiemore classic selection olorosso sherry finish 6/750ml 43%': 745,
#  'towiemore classic selection px finish 6/750 43%': 746,
#  '': 747,
#  'sweetwater brand family': 748,
#  '2 fools cider brand family': 749,
#  '2 row brand family': 750,
#  '2 silos brand family': 751,
#  '2 towns brand family': 752,
#  '2sp brand family': 753,
#  '3 badge brand family': 754,
#  '3 brothers brand family': 755,
#  '3 daughters brand family': 756,
#  '3 daughters cider brand family': 757,
#  '3 daughters florida hard seltzer brand family': 758,
#  '3 fonteinen brand family': 759,
#  '3 nations brand family': 760,
#  '3 sheeps brand family': 761,
#  '3 sheeps hard seltzer brand family': 762,
#  '3 stars brand family': 763,
#  '3rd rock brand family': 764,
#  '3rd sign brand family': 765,
#  '3rd wave brand family': 766,
#  '4 hands brand family': 767,
#  '4 pines brand family': 768,
#  '4 sons brand family': 769,
#  '4th tap co op brand family': 770,
#  '5 rabbit brand family': 771,
#  '6 bears &amp; a goat brand family': 772,
#  '6 point brand family': 773,
#  '7 clans brand family': 774,
#  '7 hills brand family': 775,
#  '7 locks brand family': 776,
#  '7 locks devils alley ipa brand family': 777,
#  '7 seas brand family': 778,
#  '7venth sun brand family': 779,
#  '8 wired brand family': 780,
#  '8th wonder brand family': 781,
#  '10 barrel': 782,
#  '10 barrel brand family': 783,
#  '10 barrel cider brand family': 784,
#  '10 barrel hard seltzer brand family': 785,
#  '10 torr': 786,
#  '10 torr brand family': 787,
#  '11 below brand family': 788,
#  '12 gates brand family': 789,
#  '13 stripes brand family': 790,
#  '14th star brand family': 791,
#  '16 mile brand family': 792,
#  '18th street brand family': 793,
#  '19 crimes brand family': 794,
#  '26 degree brand family': 795,
#  '32 north coastal brand family': 796,
#  '33 export brand family': 797,
#  '42 north brand family': 798,
#  '54 40 brand family': 799,
#  '56 brand family': 800,
#  '81bay brand family': 801,
#  '101 cider house brand family': 802,
#  '101 north brand family': 803,
#  '360': 804,
#  '512 pecan brand family': 805,
#  '559 bba brand family': 806,
#  '603 brand family': 807,
#  '603 hard seltzer brand family': 808,
#  '902 daddy brand family': 809,
#  '903 brand family': 810,
#  '1010': 811,
#  '1220': 812,
#  '1800': 813,
#  'a los': 814,
#  'a:m brand family': 815,
#  'abandoned building brand family': 816,
#  'abbey de leffe brand family': 817,
#  'abbot ale brand family': 818,
#  'abita hard soda brand family': 819,
#  'abita spring loaded spiked sparkling brand family': 820,
#  'abk brand family': 821,
#  'able ebenezer brand family': 822,
#  'abnormal brand family': 823,
#  'absolut': 824,
#  'absolution brand family': 825,
#  'ac dc brand family': 826,
#  'ace brand family': 827,
#  'ace pilsener brand family': 828,
#  'achel brand family': 829,
#  'achouffe brand family': 830,
#  'acme california brand family': 831,
#  'actual brand family': 832,
#  'adelberts brand family': 833,
#  'adirondack brand family': 834,
#  'adirondack cider brand family': 835,
#  'adnams brand family': 836,
#  'adroit theory brand family': 837,
#  'adventure brewing brand family': 838,
#  'aecht schlenkerla brand family': 839,
#  'aero plains brand family': 840,
#  'aeronaut brand family': 841,
#  'afanasy brand family': 842,
#  'affligem brand family': 843,
#  'afterglow hard kombucha brand family': 844,
#  'aftershock brand family': 845,
#  'aguila brand family': 846,
#  'ahnapee brand family': 847,
#  'akademia skal brand family': 848,
#  'alameda brand family': 849,
#  'alamo brand family': 850,
#  'alarmist brand family': 851,
#  'alaskan hard seltzer brand family': 852,
#  'ale asylum brand family': 853,
#  'ale industries brand family': 854,
#  'aleman brand family': 855,
#  'alementary brand family': 856,
#  'alera brillante brand family': 857,
#  'alesmith brand family': 858,
#  'alesong brand family': 859,
#  'alewerks brand family': 860,
#  'alibi brand family': 861,
#  'all relation brand family': 862,
#  'allagash brand family': 863,
#  'almaza brand family': 864,
#  'alpine beer brand family': 865,
#  'altamont brand family': 866,
#  'alter brand family': 867,
#  'alter ego cider brand family': 868,
#  'altes brand family': 869,
#  'altstadt brand family': 870,
#  'alvinne brand family': 871,
#  'amador brand family': 872,
#  'amager brand family': 873,
#  'amarcord brand family': 874,
#  'american caboose brand family': 875,
#  'american cider brand family': 876,
#  'american river brand family': 877,
#  'amherst brand family': 878,
#  'amstel brand family': 879,
#  'ancestry brand family': 880,
#  'ancient city brand family': 881,
#  'andechser brand family': 882,
#  'andrews brand family': 883,
#  'andriivs.kiy brand family': 884,
#  'angel city brand family': 885,
#  'angry minnow brand family': 886,
#  'angry orchard brand family': 887,
#  'anonymous brand family': 888,
#  'anthem brand family': 889,
#  'antietam brand family': 890,
#  'antiques on high brand family': 891,
#  'anyday brand family': 892,
#  'anzalone brand family': 893,
#  'apocalypse brand family': 894,
#  'appalachian brand family': 895,
#  'appalachian mountain brand family': 896,
#  'appalachian mountain cider brand family': 897,
#  'appalachian mountain hard seltzer brand family': 898,
#  'apple bite brand family': 899,
#  'apple knocker hard cider brand family': 900,
#  'apple outlaw brand family': 901,
#  'ararat brand family': 902,
#  'arbor brand family': 903,
#  'arcadia brand family': 904,
#  'arches brand family': 905,
#  'arctic summer brand family': 906,
#  'ardent brand family': 907,
#  'argus brand family': 908,
#  'argus cider brand family': 909,
#  'armadillo brand family': 910,
#  'arnold palmer brand family': 911,
#  'around the bend brand family': 912,
#  'arsenalnoye brand family': 913,
#  'artifact brand family': 914,
#  'artifex brand family': 915,
#  'artisanal brew brand family': 916,
#  'artisinal brew works brand family': 917,
#  'artys': 918,
#  'asahi brand family': 919,
#  'asbury park brand family': 920,
#  'asheville brand family': 921,
#  'ashland hard seltzer brand family': 922,
#  'aslan brand family': 923,
#  'aspall brand family': 924,
#  'aspen edge brand family': 925,
#  'assorted brand family': 926,
#  'athletic brand family': 927,
#  'atlanta brand family': 928,
#  'atlanta craft brand family': 929,
#  'atlantic bar harbor brand family': 930,
#  'atlantic beach brand family': 931,
#  'atlas brand family': 932,
#  'atlas cider brand family': 933,
#  'atwater brand family': 934,
#  'atwater spiked sparkling water brand family': 935,
#  'auburn brand family': 936,
#  'audacity brand family': 937,
#  'augustiner brau brand family': 938,
#  'aurochs brand family': 939,
#  'austin beerworks brand family': 940,
#  'austin brothers brand family': 941,
#  'austin cocktail': 942,
#  'austin eastciders brand family': 943,
#  'austin eastciders spiked seltzer brand family': 944,
#  'aval cider brand family': 945,
#  'avery hard seltzer brand family': 946,
#  'aviator brand family': 947,
#  'avid brand family': 948,
#  'avondale brand family': 949,
#  'avtorske brand family': 950,
#  'axe head fmb brand family': 951,
#  'ayinger brand family': 952,
#  'b &amp; i brand family': 953,
#  'b honey brand family': 954,
#  'b nektar meadery brand family': 955,
#  'b w brand family': 956,
#  'bacardi': 957,
#  'bacardi silver brand family': 958,
#  'bacchus brand family': 959,
#  'back bay brand family': 960,
#  'back east brand family': 961,
#  'back forty brand family': 962,
#  'back pew brand family': 963,
#  'backlash brand family': 964,
#  'backpocket brand family': 965,
#  'backshore brand family': 966,
#  'backside brand family': 967,
#  'backswing brand family': 968,
#  'backwoods brand family': 969,
#  'bad beat brand family': 970,
#  'bad granny brand family': 971,
#  'bad lab brand family': 972,
#  'bad larrys brand family': 973,
#  'bad seed brand family': 974,
#  'bad sons brand family': 975,
#  'bad weather brand family': 976,
#  'badass brand family': 977,
#  'badass cider brand family': 978,
#  'baderbrau brand family': 979,
#  'badger hill brand family': 980,
#  'badger state brewing brand family': 981,
#  'baerlic brand family': 982,
#  'baffin brand family': 983,
#  'baileys': 984,
#  'bainbridge island brand family': 985,
#  'baja brand family': 986,
#  'bakfish brand family': 987,
#  'baladin brand family': 988,
#  'bale breaker brand family': 989,
#  'ballantine brand family': 990,
#  'baltika brand family': 991,
#  'banded brand family': 992,
#  'bank brand family': 993,
#  'banks brand family': 994,
#  'banrock': 995,
#  'bantam cider brand family': 996,
#  'bantam fmb brand family': 997,
#  'bar harbor brand family': 998,
#  'baraboo brand family': 999,
#  'baraboo cider brand family': 1000,
#  ...}

# %%
masterdict = {}
masterdict.update(dashboard_dict)
masterdict.update(metric_dict)
masterdict.update(descriptor_dict)

# %%
for k,v in masterdict.items():
    masterdict[k] = {}

# %%
autocomplete = AutoComplete(words = masterdict)

# %%
autosuggestions = autocomplete.search(word = 'sales', max_cost= 3, size = 100)
start = timeit.default_timer()
dashboard_suggestions_auto = dashboard_names_suggestion(master,autosuggestions)

search_output = []
search_output = list(dict.fromkeys(dashboard_suggestions_auto))

stop = timeit.default_timer()
execution_time = stop - start

print("Program Executed in "+str(execution_time))
search_output[:10]
# Out:
# Program Executed in 0.24595099600082904
# ['depletions month cube with inventory and shipmentments',
#  'depletionsletions cube',
#  'retail month cube',
#  'retail cube to  brand quality level',
#  'retail cube to brand level',
#  'retail cube with reorder to rollup',
#  'sales team opportunitshis year ',
#  'sales manager dashboard',
#  'depletionsletions',
#  'sales team tracker ']

# %% [markdown]
# ## Method 5:  Wordnet

# %% [markdown]
# ## Comparisions

# %% [markdown]
# # Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

search_terms = 'dollar sales'
documents = text

doc_vectors = TfidfVectorizer().fit_transform([search_terms] + documents)

cosine_similarities = linear_kernel(doc_vectors[0:1], doc_vectors).flatten()
document_scores = [item.item() for item in cosine_similarities[1:]]

tuples = list(zip(text,document_scores))
df_scores = pd.DataFrame(tuples, columns = ['text','document_scores'])
df_scores.sort_values('document_scores', ascending =False).head(10)

# %%
doc_vectors.nonzero()

# %% [markdown]
# # Using Glove's Model

# %%
from re import sub
from gensim.utils import simple_preprocess

query_string = 'area'
documents = text

stopwords = ['the', 'and', 'are', 'a']

# From: https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/soft_cosine_tutorial.ipynb
def preprocess(doc):
    # Tokenize, clean up input document string
    doc = sub(r'<img[^<>]+(>|$)', " image_token ", doc)
    doc = sub(r'<[^<>]+(>|$)', " ", doc)
    doc = sub(r'\[img_assist[^]]*?\]', " ", doc)
    doc = sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', " url_token ", doc)
    return [token for token in simple_preprocess(doc, min_len=0, max_len=float("inf")) if token not in stopwords]

# Preprocess the documents, including the query string
corpus = [preprocess(document) for document in documents]
query = preprocess(query_string)




# Build the term dictionary, TF-idf model
dictionary = Dictionary(corpus+[query])
tfidf = TfidfModel(dictionary=dictionary)

# Create the term similarity matrix.  
similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)

# Compute Soft Cosine Measure between the query and the documents.
# From: https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/soft_cosine_tutorial.ipynb
query_tf = tfidf[dictionary.doc2bow(query)]

index = SoftCosineSimilarity(
            tfidf[[dictionary.doc2bow(document) for document in corpus]],
            similarity_matrix)

doc_similarity_scores = index[query_tf]

# Output the sorted similarity scores and documents
sorted_indexes = np.argsort(doc_similarity_scores)[::-1]
for idx in sorted_indexes:
    print(f'{idx} \t {doc_similarity_scores[idx]:0.3f} \t {documents[idx]}')

# %%
# import gensim.downloader as api
# from gensim.corpora import Dictionary
# from gensim.models import TfidfModel
# from gensim.models import WordEmbeddingSimilarityIndex
# from gensim.similarities import SparseTermSimilarityMatrix
# from gensim.similarities import SoftCosineSimilarity

# # Load the model: this is a big file, can take a while to download and open
# glove = api.load("glove-wiki-gigaword-50")    
# similarity_index = WordEmbeddingSimilarityIndex(glove)

# %%
# Build the term dictionary, TF-idf model
dictionary = Dictionary(corpus+[query])
tfidf = TfidfModel(dictionary=dictionary)

# Create the term similarity matrix.  
similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)

# Compute Soft Cosine Measure between the query and the documents.
# From: https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/soft_cosine_tutorial.ipynb
query_tf = tfidf[dictionary.doc2bow(query)]

index = SoftCosineSimilarity(
            tfidf[[dictionary.doc2bow(document) for document in corpus]],
            similarity_matrix)

doc_similarity_scores = index[query_tf]

# Output the sorted similarity scores and documents
sorted_indexes = np.argsort(doc_similarity_scores)[::-1]
for idx in sorted_indexes:
    print(f'{idx} \t {doc_similarity_scores[idx]:0.3f} \t {documents[idx]}')
